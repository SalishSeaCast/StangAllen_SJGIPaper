# %%
import numpy as np
import matplotlib.pyplot as plt
import arrow
import datetime
import xarray as xr
import os
import cmocean.cm as cm
import matplotlib.cm as cma
import scipy.interpolate as interp
from matplotlib.collections import PatchCollection
import matplotlib.dates as mpl_dates
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FormatStrFormatter
import datetime as dt 
from matplotlib.patches import Rectangle
from IPython.display import Image, display
import pandas as pd

# %%
variables = ['final_salt','final_transp','final_lon','final_lat','final_depth','final_section','final_z','final_temp','init_lon','init_z','init_salt','init_temp','init_transp','final_age','final_dens','init_dens','init_lat']

#Function to extract data from 1 section
def get_secdata(datafile,sectionnum):
    
    variables = ['final_salt','final_transp','final_lon','final_lat','final_depth','final_section','final_z','final_temp','init_lon','init_z','init_salt','init_temp','init_transp','final_age','final_dens','init_dens','init_lat']
    
    dict_var = {}
    
    idx = np.where(datafile['final_section']==sectionnum)
    
    for var in variables:
        if var == 'final_age':
            agetd = datafile[var].values
            agehr = agetd.astype('float64')/(10**9*3600)
            age = agehr[idx]
            dict_var[var] = xr.DataArray(age)
        else:
            data_sec = datafile[var]
            dict_var[var] = data_sec[idx]
        
    
    return dict_var      

def draw_patches(fmask, ll, ul, u_lons, w_depths,m2lon):
    topo = []
    for i in range(ll, ul):
        for j in range(39):
            if fmask[j, i] == 0:
                try:
                    rect = Rectangle((u_lons[i]/m2lon, w_depths[j+1]), u_lons[i+1]/m2lon-u_lons[i]/m2lon, w_depths[j+2]-w_depths[j+1])
                    topo.append(rect)
                except:
                    pass

    pc = PatchCollection(topo, facecolors='lightgray', edgecolors='none')
    return(pc)


def plotTS(axn,var,lonsec,zsec,varsec,lonW,lonE,latgridi,depi,time,title,cblabel,ylabel,vmin=None,vmax=None):
    
    latgridf = latgridi-1
    fmask = mesh.fmask[0, :, latgridf]
    tmask = mesh.tmask[0]
    
    lons = data.init_lon[(data.final_section != 0)]
    
    f_lons = mesh.glamf[0, latgridf]
    u_lons = mesh.glamv[0, latgridf]
    w_depths = mesh.gdepw_1d

    m2lon = ((u_lons[lonE]-u_lons[lonW])/(mesh.e2f[0, latgridi, lonW:lonE].sum())).values #degrees/m
    
    cmap = cm.deep
    
    m2lon = ((u_lons[lonE]-u_lons[lonW])/(mesh.e2f[0, latgridi, lonW:lonE].sum())).values #degrees/m
    
    arrw,xe,ye,im = axn.hist2d(lonsec/m2lon,df(zsec)[0],weights=varsec,cmap=cmap,bins=[np.array(f_lons[lonW:lonE:1]/m2lon),w_depths[0,0:depi]])
    arrnw,xe2,ye2,im2 = axn.hist2d(lonsec/m2lon,df(zsec)[0],cmap=cmap,bins=[np.array(f_lons[lonW:lonE:1]/m2lon),w_depths[0,0:depi]])
    
    arr3 = arrw/arrnw
    
    X,Y = np.meshgrid(xe,ye)
    
    im = axn.pcolormesh(X,Y,arr3.T,vmin=vmin,vmax=vmax)
    axn.set_xlabel('Longitude (°E)')
    axn.set_title(title)
    axn.invert_yaxis()
    axn.set_xticks(np.linspace(f_lons[lonW]/m2lon,f_lons[lonE-1]/m2lon,2))
    axn.set_xticklabels(['{:.2f}'.format(label) for label in np.linspace(f_lons[lonW],f_lons[lonE-1],2)])
    
    if cblabel == True:
        cb = fig.colorbar(im,ax=axn)
        
        if var == 'temp':
            cb.set_label('Temperature (°C)')
        if var == 'sal':
            cb.set_label('Salinity (g/kg)')
            
    if ylabel == True:
        axn.set_ylabel('Depth (m)')
    else:
        axn.set_yticks([])
        
def get_datat(datafile,section, starttime, endtime):
    final_section = datafile.final_section
    final_transport = datafile.final_transp
    transports = np.sum(np.where(final_section == section, final_transport, 0)) 
    return transports/(endtime-starttime+1)

# %%
def plotCS(axv,lonsec,zsec,transpsec,lonW,lonE,latgridi,depi,vmax,time,title,cblabel,ylabel):
    
    latgridf = latgridi-1
    fmask = mesh.fmask[0, :, latgridf]
    tmask = mesh.tmask[0]
    
    lons = data.init_lon[(data.final_section != 0)]
    
    f_lons = mesh.glamf[0, latgridf]
    u_lons = mesh.glamv[0, latgridf]
    w_depths = mesh.gdepw_1d

    m2lon = ((u_lons[lonE]-u_lons[lonW])/(mesh.e2f[0, latgridi, lonW:lonE].sum())).values #degrees/m
    
    cmap = cm.deep
    
    arr,xe,ye,im = axv.hist2d(lonsec/m2lon,df(zsec)[0],weights=transpsec,cmap=cmap,bins=[np.array(f_lons[lonW:lonE:1]/m2lon),w_depths[0,0:depi]],
                              density=True,vmax=vmax
                                )
    
    X,Y = np.meshgrid(xe,ye)
    
    im = axv.pcolormesh(X,Y,arr.T*np.sum(transpsec)/time,cmap=cmap,vmax=vmax)
    
    axv.invert_yaxis()
    axv.set_title(title)
    axv.set_xlabel('Longitude (°E)')
    axv.set_xticks(np.linspace(f_lons[lonW+2]/m2lon,f_lons[lonE-2]/m2lon,2))
    axv.xaxis.set_major_formatter(FormatStrFormatter(f"%.{2}f"))
    axv.set_xticklabels(['{:.2f}'.format(label) for label in np.linspace(f_lons[lonW+2],f_lons[lonE-2],2)])
    axv.set_xticklabels(np.round(np.linspace(f_lons[lonW+2],f_lons[lonE-2],2),2))
    
    pc = draw_patches(fmask, lonW, lonE, np.array(u_lons), np.array(w_depths[0]),m2lon)
    axv.add_collection(pc)

    if cblabel == True:
        cb = fig.colorbar(im,ax=axv)
        cb.set_label('Transport (m/s)')
    
    if ylabel == True:
        axv.set_ylabel('Depth (m)')
        
    else: 
        axv.set_yticklabels([])

# %%
def plotCS_NW(axv,lonsec,zsec,transpsec,lonW,lonE,latgridi,depi,vmax,time,title,cblabel,ylabel):
    
    latgridf = latgridi-1 #actually lon
    fmask = mesh.fmask[0,:,:,latgridf] # Giving mask of longitudes
    tmask = mesh.tmask[0]
    
    lons = data.init_lat[(data.final_section != 0)]
    
    f_lons = mesh.gphif[0,:, latgridf]
    u_lons = mesh.gphiv[0,:, latgridf]
    w_depths = mesh.gdepw_1d

    m2lon = ((u_lons[lonE]-u_lons[lonW])/(mesh.e2f[0, latgridi, lonW:lonE].sum())).values #degrees/m
    
    cmap = cm.deep
    
    arr,xe,ye,im = axv.hist2d(lonsec/m2lon,df(zsec)[0],weights=transpsec,cmap=cmap,bins=[np.array(f_lons[lonW:lonE:1]/m2lon),w_depths[0,0:depi]],
                              density=True,vmax=vmax
                                )
    
    X,Y = np.meshgrid(xe,ye)
    
    im = axv.pcolormesh(X,Y,arr.T*np.sum(transpsec)/time,cmap=cmap,vmax=vmax)
    
    axv.invert_yaxis()
    axv.set_title(title)
    axv.set_xlabel('Latitude (°W)')
    axv.set_xticks(np.linspace(f_lons[lonW+2]/m2lon,f_lons[lonE-2]/m2lon,2))
    axv.xaxis.set_major_formatter(FormatStrFormatter(f"%.{2}f"))
    axv.set_xticklabels(['{:.2f}'.format(label) for label in np.linspace(f_lons[lonW+2],f_lons[lonE-2],2)])
    axv.set_xticklabels(np.round(np.linspace(f_lons[lonW+2],f_lons[lonE-2],2),2))
    
    pc = draw_patches(fmask, lonW, lonE, np.array(u_lons), np.array(w_depths[0]),m2lon)
    axv.add_collection(pc)

    if cblabel == True:
        cb = fig.colorbar(im,ax=axv)
        cb.set_label('Transport (m/s)')
    
    if ylabel == True:
        axv.set_ylabel('Depth (m)')
        
    else: 
        axv.set_yticklabels([])

# %% [markdown]
# ## Import data

# %%
data = xr.open_dataset('/ocean/cstang/MOAD/analysis-camryn/Ariane/for_jan18/for_straight_01jan18_s7t28/ariane_positions_quantitative.nc')
mesh = xr.open_dataset('/home/sallen/MEOPAR/grid/mesh_mask202108.nc')
df = interp.interp1d(mesh.z,mesh.gdepw_1d) # Interpolate to get same binning scheme as SalishSeaCast

# %%
#Importing data and calculating section transport 
import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)

# files = ['forpr_ros3','forpr_haro3','forvs_haro3']
files = ['foradm_jan18_3','for_jan18_3']
namen = ['datafvs']

starttime = 1
endtime = 24
sectionnum = [0,1,2,3,4,5,6,7,8]

date = dt.datetime(2018,1,1)
enddate = dt.datetime(2018,12,31)

dates = []
datelist_vs = []

while date <= enddate:
    dates.append(date.strftime('%d%b%y').lower())
    datelist_vs.append(date)
    date+=dt.timedelta(days=1)
     
dicts = {}

for i,file in enumerate(files):
    dict_i = {}
    
    for date in dates:
        name = '/ocean/cstang/MOAD/analysis-camryn/Ariane/' + file + '/' + date + '_s1t50/ariane_positions_quantitative.nc'
        
        if os.path.isfile(name):
            dict_i[date] = xr.open_dataset(name)
        else:
            name = '/ocean/cstang/MOAD/analysis-camryn/Ariane/' + file + '/' + date + '_s1t28/ariane_positions_quantitative.nc'
            
            if os.path.isfile(name):
                dict_i[date] = xr.open_dataset(name)
            
            
        
    dicts[file] = dict_i
    
dict_sectiontransp = {}

for file in files:
    st_dict = {}
    for var in dicts[file].keys():
        if var not in st_dict:
            st_dict[var] = []
        for section in sectionnum:
            st_dict[var].append(get_datat(dicts[file][var],section,starttime,endtime))
        dict_sectiontransp[file] = st_dict

dict_age = {}

for file in files:
    a_dict = {}
    
    for date in dicts[file].keys():
        if date not in a_dict:
            a_dict[date] = []
        for section in sectionnum:
            allvar = get_secdata(dicts[file][date],section)
            a_dict[date].append(np.mean(allvar['final_age'][allvar['final_age']>=24]))
    dict_age[file] = a_dict

age_2018 = {}

for file in files:
    
    if file not in age_2018:
        age_2018[file] = {}
    
    for section in sectionnum:
        
        if section not in age_2018[file]:
            
            age_2018[file][section] = []
            
        for date in dicts[file].keys():
            
            age_2018[file][section].append(dict_age[file][date][section])
            
transp_2018 = {}

for file in files:
    
    transp_2018[file] = []
    
    for date in dates:
        try:
            transp_2018[file].append(np.sum(dict_sectiontransp[file][date][2:]))
        except:
            pass
        
sectransp_2018 = {}

for file in files:
    sectransp_2018[file] = {}
    
    for section in sectionnum:
        if section not in sectransp_2018[file]:
            sectransp_2018[file][section] = []
            
        for date in dates:
            try:
                sectransp_2018[file][section].append(dict_sectiontransp[file][date][section])
            except:
                pass

# %%
len(dicts['backVS_jan18_3'].keys())
# Out:
# 365

# %%
dict_secdata = {}

for file in files:
    
    if file not in dict_secdata:
        dict_secdata[file] = {}
    
    for section in sectionnum:
        
        if section not in dict_secdata[file]:
            
            dict_secdata[file][section] = {}
            
        for date in dicts[file].keys():
            
            dict_secdata[file][section][date] = get_secdata(dicts[file][date],section)

# %%
dict_secdata['for_jan18'][0]
# Out:
# {'01jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 22809)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 22809)>
#   array([0.17923602, 0.37850388, 0.84310749, ..., 0.68407683, 0.54711846,
#          0.55207634])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 22809)>
#   [22809 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 22809)>
#   [22809 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '02jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 21999)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 21999)>
#   array([36.97848134, 47.88296529, 57.78272789, ...,  0.71874939,
#           1.54442997,  1.34117717])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 21999)>
#   [21999 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 21999)>
#   [21999 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '03jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 20625)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 20625)>
#   array([0.56657957, 0.60463533, 0.6350967 , ..., 1.47835893, 1.29485352,
#          0.54278229])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 20625)>
#   [20625 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 20625)>
#   [20625 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '04jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 19977)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 19977)>
#   array([0.63404811, 1.22609906, 0.965856  , ..., 3.15628014, 3.14996224,
#          2.24233529])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 19977)>
#   [19977 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 19977)>
#   [19977 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '05jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 18427)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 18427)>
#   array([1.46836592, 2.6746153 , 1.86849857, ..., 5.55104725, 5.08565168,
#          5.23528968])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 18427)>
#   [18427 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 18427)>
#   [18427 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '06jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 17934)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 17934)>
#   array([4.6486942 , 4.49031848, 4.08398388, ..., 7.41059921, 7.15174662,
#          9.71647458])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 17934)>
#   [17934 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 17934)>
#   [17934 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '07jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 18474)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 18474)>
#   array([ 5.80155866,  5.65648459,  6.13252642, ..., 48.05127156,
#           0.30097018, 73.38735876])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 18474)>
#   [18474 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 18474)>
#   [18474 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '08jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 18942)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 18942)>
#   array([ 22.36922301, 171.89474422,  10.40516343, ...,   0.74644038,
#            2.21108702,   6.22628973])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 18942)>
#   [18942 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 18942)>
#   [18942 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '09jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 18848)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 18848)>
#   array([ 97.35972711, 123.48931231, 198.28304987, ...,  23.55337547,
#            2.7699866 ,  22.99217956])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 18848)>
#   [18848 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 18848)>
#   [18848 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '10jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 19105)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 19105)>
#   array([100.72311956,  48.84180655,  23.5576685 , ...,   2.30175773,
#            1.68094196,   1.24659004])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 19105)>
#   [19105 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 19105)>
#   [19105 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '11jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 20270)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 20270)>
#   array([51.46494396,  0.32637841,  3.22024899, ...,  0.5994932 ,
#           0.51819533,  0.57294376])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 20270)>
#   [20270 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 20270)>
#   [20270 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '12jan18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 20579)>
#   [20579 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 20579)>
#   [20579 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 20579)>
#   [20579 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 20579)>
#   [20579 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
# ...
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 20079)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 20079)>
#   [20079 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 20079)>
#   [20079 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 20079)>
#   [20079 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 20079)>
#   [20079 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 20079)>
#   [20079 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 20079)>
#   [20079 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 20079)>
#   [20079 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 20079)>
#   array([  4.83861386,   6.14249168,   6.12220051, ...,   0.28488034,
#          147.96748384,  75.60366911])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 20079)>
#   [20079 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 20079)>
#   [20079 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 20079)>
#   [20079 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '29dec18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 21157)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 21157)>
#   array([8.97746245e+00, 1.70243954e+02, 1.67073389e-01, ...,
#          1.38535028e+00, 4.96193880e+01, 1.04935944e+01])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 21157)>
#   [21157 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 21157)>
#   [21157 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '30dec18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 20896)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 20896)>
#   array([22.68337739, 74.54577366, 73.83094688, ...,  0.99848054,
#           1.80082184,  1.66152517])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 20896)>
#   [20896 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 20896)>
#   [20896 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension},
#  '31dec18': {'final_salt': <xarray.DataArray 'final_salt' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_salt ?
#       longname:  Final salinity
#       units:     psu,
#   'final_transp': <xarray.DataArray 'final_transp' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_transp ?
#       longname:  Final transport
#       units:     m3/s,
#   'final_lon': <xarray.DataArray 'final_lon' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lon ?
#       longname:  Final position in longitude
#       units:     No dimension,
#   'final_lat': <xarray.DataArray 'final_lat' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_lat ?
#       longname:  Final position in latitude
#       units:     No dimension,
#   'final_depth': <xarray.DataArray 'final_depth' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_depth?
#       longname:  Final position in depth
#       units:     No dimension,
#   'final_section': <xarray.DataArray 'final_section' (ntraj: 19210)>
#   array([0., 0., 0., ..., 0., 0., 0.])
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_section ?
#       longname:  Final section
#       units:     No dimension,
#   'final_z': <xarray.DataArray 'final_z' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_z ?
#       longname:  Final position in z (or k)
#       units:     No dimension,
#   'final_temp': <xarray.DataArray 'final_temp' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_temp ?
#       longname:  Final temperature
#       units:     degres,
#   'init_lon': <xarray.DataArray 'init_lon' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lon ?
#       longname:  Initial position in longitude
#       units:     No dimension,
#   'init_z': <xarray.DataArray 'init_z' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_z ?
#       longname:  Initial position in k
#       units:     No dimension,
#   'init_salt': <xarray.DataArray 'init_salt' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_salt ?
#       longname:  Initial salinity
#       units:     psu,
#   'init_temp': <xarray.DataArray 'init_temp' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_temp ?
#       longname:  Initial temperature
#       units:     degres,
#   'init_transp': <xarray.DataArray 'init_transp' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_transp ?
#       longname:  Initial transport
#       units:     m3/s,
#   'final_age': <xarray.DataArray (dim_0: 19210)>
#   array([0.22557467, 0.96558957, 0.30050285, ..., 0.41806298, 0.53302564,
#          0.13146127])
#   Dimensions without coordinates: dim_0,
#   'final_dens': <xarray.DataArray 'final_dens' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is final_dens ?
#       longname:  Final density
#       units:     ...,
#   'init_dens': <xarray.DataArray 'init_dens' (ntraj: 19210)>
#   [19210 values with dtype=float32]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_dens ?
#       longname:  Initial density
#       units:     ...,
#   'init_lat': <xarray.DataArray 'init_lat' (ntraj: 19210)>
#   [19210 values with dtype=float64]
#   Dimensions without coordinates: ntraj
#   Attributes:
#       title:     What is init_lat ?
#       longname:  Initial position in latitude
#       units:     No dimension}}

# %%
ddd = {}
months = ['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']



for file in files:
    if file not in ddd:
        ddd[file] = {}
    
    for var in dict_secdata[file][section][date].keys():
    
        if var not in ddd[file]:
            ddd[file][var] = {}
        
        for section in sectionnum:
        
            if section not in ddd[file][var]:
            
                ddd[file][var][section] = {}
            
            for month in range(len(months)):
            
                if months[month] not in ddd[file][var][section]:
                    ddd[file][var][section][months[month]] = []

                for ii,date in enumerate(dicts[file].keys()):
                    
                    if datelist_vs[ii].month == month+1:
                        ddd[file][var][section][months[month]].extend(dict_secdata[file][section][date][var].values.tolist())

# %%
# Combining all months into 1 array
# Change file, var, and section for each combination to be saved

file = 'foradm_jan18_3'
var = 'final_transp'
section = 4

numrow = np.max([len(ddd[file][var][section][month]) for month in months])

data = np.zeros(numrow)*np.nan
data[:len(ddd[file][var][section]['jan'])] = ddd[file][var][section]['jan']

for month in months[1:]:
    data_int = np.zeros(numrow)*np.nan
    data_int[:len(ddd[file][var][section][month])] = ddd[file][var][section][month]
    data = np.vstack([data,data_int])

data_df = pd.DataFrame(data.T,index=None)

# %%
#Saving combined data as a csv file
#Change filename to match the above file, var, section

data_df.to_csv('/ocean/cstang/MOAD/analysis-camryn/combined_from_ariane/admtoros3_finaltransp.csv',index=None,header=months)
test = pd.read_csv('/ocean/cstang/MOAD/analysis-camryn/combined_from_ariane/admtoros3_finaltransp.csv')
test
# Out:
#               jan         feb         mar         apr         may         jun  \
# 0      668.479184  233.323076  561.132001  440.353915  372.667408  128.609619
# 1      728.935213  296.077951  585.842403  257.441413  289.186308    9.273696
# 2      732.592430  275.266912  511.126742   37.769752  657.660874   62.209916
# 3      709.923133  399.087682  497.130490  618.365094  549.352145  395.531533
# 4      832.822926  136.068661  551.830776  578.629486  440.941114   13.470636
# ...           ...         ...         ...         ...         ...         ...
# 2642  1445.625674         NaN         NaN         NaN         NaN         NaN
# 2643  1675.259935         NaN         NaN         NaN         NaN         NaN
# 2644   629.332024         NaN         NaN         NaN         NaN         NaN
# 2645   605.826859         NaN         NaN         NaN         NaN         NaN
# 2646   652.065043         NaN         NaN         NaN         NaN         NaN
#
#              jul         aug         sep         oct         nov         dec
# 0     251.495368  144.096714    7.723971  158.264277  121.810690  260.008462
# 1     116.877352   85.272260  232.390970   37.474943  131.258477   25.638104
# 2     293.203366  122.532273  728.887192  390.883524   81.700672  337.457383
# 3     245.058466  122.741737  577.198228  170.106595    4.269635  156.500394
# 4     873.572842  311.907555  654.109634  347.120649  157.756878  120.503257
# ...          ...         ...         ...         ...         ...         ...
# 2642         NaN         NaN         NaN         NaN         NaN         NaN
# 2643         NaN         NaN         NaN         NaN         NaN         NaN
# 2644         NaN         NaN         NaN         NaN         NaN         NaN
# 2645         NaN         NaN         NaN         NaN         NaN         NaN
# 2646         NaN         NaN         NaN         NaN         NaN         NaN
#
# [2647 rows x 12 columns]
